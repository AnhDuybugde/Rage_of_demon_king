# %%
from ppadb.client import Client

# ADB server mặc định chạy port 5037
client = Client(host="127.0.0.1", port=5037)

device = client.device("127.0.0.1:5555")

print(device.shell("echo Hello from LDPlayer"))
print(device.shell("getprop ro.product.model"))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Nhập vào terminal 

"""
& "C:\LDPlayer\LDPlayer9\adb.exe" connect 127.0.0.1:5555     để connect

adb disconnect        để disconnect 
 """

# %%
print('hi')
